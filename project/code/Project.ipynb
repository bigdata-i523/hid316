# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
weather = pd.read_csv("C:\Python27\Scripts\Wunderground_Data.csv")

# %%
weather.head()
# Out:
#          Date      Time         PWS  Temperature  Humidity  Pressure
# 0  11/21/2017  12:00 AM  Deer Ridge           57      0.50        30
# 1  11/21/2017  12:40 AM  Deer Ridge           56      0.51        30
# 2  11/21/2017   1:10 AM  Deer Ridge           56      0.51        30
# 3  11/21/2017   1:40 AM  Deer Ridge           56      0.50        30
# 4  11/21/2017   2:30 AM  Deer Ridge           55      0.51        30

# %%
weather = pd.read_csv("C:\Python27\Scripts\Wunderground_Data.csv")
weathernew = weather[['Date', 'PWS', 'Temperature']]

plt.figure(figsize=(20,10))

plt.ylim(65, 85)
plt.bar(weathernew['PWS'], weathernew['Temperature'])

plt.xlabel('Weather Stations')
plt.ylabel('Temperature (F)')
plt.title('Weekly Record Temperatures')
plt.legend()

plt.show()

# %%
weather = pd.read_csv("C:\Python27\Scripts\Wunderground_Data.csv")
weathernew = weather[['Date', 'PWS', 'Humidity']]

plt.figure(figsize=(20,15))

plt.ylim(.5, 1.0)
plt.bar(weathernew['PWS'], weathernew['Humidity'])

plt.xlabel('Weather Stations')
plt.ylabel('Humidity (%)')
plt.title('Weekly Record Humidity')
plt.legend()

plt.show()
